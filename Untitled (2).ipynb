# %%
name = "Ayesha Saman Hawaldar"
email = "ayesh95_saman@yahoo.in"
slack_username = "@Ayesha"
biostack = "Vaccines"
print("Name: "+name)
print("Email ID: "+email) 
print("Slack username: "+slack_username) 
print("Biostack: "+biostack)
# Out:
# Name: Ayesha Saman Hawaldar
# Email ID: ayesh95_saman@yahoo.in
# Slack username: @Ayesha
# Biostack: Vaccines
